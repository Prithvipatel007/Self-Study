# %% [markdown]
# Dot product Geometry - Algebraic vs Geometry

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as mplot3d

# %%
# Two vectors
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# Compute the angle (radians) between two vectors
ang = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

# draw them
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot([0, v1[0]], [0, v1[1]], [0, v1[2]], 'b')
ax.plot([0, v2[0]], [0, v2[1]], [0, v2[2]], 'r')

# Make the plot look nicer
ax.plot([0,0], [0,0], [-4,4], 'k--')
ax.plot([0,0], [-4,4], [0,0], 'k--')
ax.plot([-4,4], [0,0], [0,0], 'k--')

plt.title('Angle between vectors : %s rad' %ang )
plt.show()

# %%
## Equivalence of algebraic and geometric dot product formulas

# Two vectors
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# Algebraic
dp_a = np.dot(v1, v2)

#Geometric
dp_b = np.linalg.norm(v1) * np.linalg.norm(v2)*np.cos(ang)

print(dp_a, dp_b)
# Out:
# -3 -3.0000000000000013

# %%
## Vector orthogonality check - code challenge

v3 = np.array([16, -2, 4])
v4 = np.array([0.5, 2, -1])

res = np.dot(v3, v4)
print(res)
# Out:
# 0.0
